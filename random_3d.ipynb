# %%
import numpy as np
import os
from PIL import Image
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
dir_one = '/home/alex/poker/1/'
dir_two = '/home/alex/poker/2/'
dir_three = '/home/alex/poker/fwd/'

# %%
first = []
for i in sorted(os.listdir(dir_one)):
    first += [i]

# %%
second = []
for i in sorted(os.listdir(dir_two)):
    second += [i]

# %%
third = []
for i in sorted(os.listdir(dir_three)):
    third += [i]

# %% [markdown]
# ## DS part

# %%
im = Image.open(dir_one+first[0])
np.asarray(im).shape
# Out:
# (1600, 720, 3)

# %%
background = im.crop((130,80,230,180))
background
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F483DFCFB38>

# %%
back = np.asarray(background)
back.shape
# Out:
# (100, 100, 3)

# %%
r = []
for i in back:
    for b in i:
        r+= [b[0]]
print (len(r))
# Out:
# 10000

# %%
g = []
for i in back:
    for b in i:
        g+= [b[1]]
print (len(g))
# Out:
# 10000

# %%
b = []
for i in back:
    for num in i:
        b+= [num[2]]
print (len(b))
# Out:
# 10000

# %%
df = pd.DataFrame({'r': r,'b': b, 'g': g}, )
hist = df.hist(bins=5)

# %%
df.r.hist()

# %%
df.g.hist()

# %%
df.b.hist()

# %%
red_list = list(df.r.unique())
print (red_list)
# Out:
# [17, 18, 19, 20, 16, 15, 13, 12, 14, 11, 21, 22, 23, 25, 24, 26]

# %%
green_list = list(df.g.unique())
print (green_list)
# Out:
# [17, 18, 19, 20, 16, 15, 21, 22, 23, 14, 24, 25, 26, 27, 28, 29]

# %%
blue_list = list(df.b.unique())
print(blue_list)
# Out:
# [25, 26, 27, 28, 23, 22, 24, 29, 30, 31, 32, 21, 33, 20, 19, 34, 35, 36, 37, 38, 39]

# %%
def two_d(size):
    test = []
    for i in range (size):
        test += [[random.choice(red_list), random.choice(green_list), random.choice(blue_list)]]
    return test

# %%
def random_3d(a,b):
    res = []
    for i in range (a):
        res += [two_d(b)]
    return np.asarray(res)

# %% [markdown]
# ## def and result for three table

# %%
def got_rgb_list(array):
    r = []
    for i in array:
        for b in i:
            r+= [b[0]]
    g = []
    for i in array:
        for b in i:
            g+= [b[1]]  
    b = []
    for i in array:
        for num in i:
            b+= [num[2]]
            
    df = pd.DataFrame({'r': r,'b': b, 'g': g}, )
    
    red_list = list(df.r.unique())
    green_list = list(df.g.unique())
    blue_list = list(df.b.unique())    
    
    return red_list, green_list, blue_list

# %%
def two_d(size, rgb_list):
    test = []
    for i in range (size):
        test += [[random.choice(rgb_list[0]), random.choice(rgb_list[1]), random.choice(rgb_list[2])]]
    return test

# %%
def random_3d(a,b, rgb_list):
    res = []
    for i in range (a):
        res += [two_d(b,rgb_list)]
    return np.asarray(res)

# %%
img = (Image.open(dir_two+second[2]))
np.asarray(img).shape
# Out:
# (2400, 1080, 3)

# %%
second_table = (img).crop((800,400,1000,600))
second_table
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F48292B1B00>

# %%
plt.imshow(random_3d(80,200, got_rgb_list(np.asarray(second_table))))

# %%
im = Image.open(dir_one+first[0])
np.asarray(im).shape
# Out:
# (1600, 720, 3)

# %%
first_table = im.crop((130,80,230,180))
first_table
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F4829E46978>

# %%
plt.imshow(random_3d(80,200, got_rgb_list(np.asarray(first_table))))

# %%
img = (Image.open(dir_three+third[2]))
np.asarray(img).shape
# Out:
# (2400, 1080, 3)

# %%
third_table = img.crop((800,230,1000,430))
third_table
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F482A98B470>

# %%
plt.imshow(random_3d(80,200, got_rgb_list(np.asarray(third_table))))

# %%
image = cv2.imread(dir_one+first[0])

# %%
start_point = (20, 20) 
  
# Ending coordinate, here (220, 220) 
# represents the bottom right corner of rectangle 
end_point = (500, 500) 
  
# Blue color in BGR 
color = (255, 255, 255) 
  
# Line thickness of 2 px 
thickness = 10
  
# Using cv2.rectangle() method 
# Draw a rectangle with blue line borders of thickness of 2 px 
image = cv2.rectangle(image, start_point, end_point, color, thickness)

# %%
plt.imshow(image)
